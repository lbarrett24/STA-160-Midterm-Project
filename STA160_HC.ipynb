# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.cluster.hierarchy import dendrogram, linkage

# %%
# Read in cleaned data set
df = pd.read_csv("/Users/calvinatkins/Downloads/Data Sets/HD_indicators_cleaned.csv", index_col = 0)
df
# Out:
#         HeartDiseaseorAttack  HighBP  HighChol  CholCheck  BMI  Smoker  \
# 0                          0       1         1          1    3       1
# 1                          0       0         0          0    2       1
# 2                          0       1         1          1    2       0
# 3                          0       1         0          1    2       0
# 4                          0       1         1          1    1       0
# ...                      ...     ...       ...        ...  ...     ...
# 253675                     0       1         1          1    3       0
# 253676                     0       1         1          1    0       0
# 253677                     0       0         0          1    2       0
# 253678                     0       1         0          1    1       0
# 253679                     1       1         1          1    2       0
#
#         Stroke  Diabetes  PhysActivity  Fruits  ...  NoDocbcCost  GenHlth  \
# ...

# %%
# Selecting data of interest
data = df[['HeartDiseaseorAttack', 'Age']]
data.to_numpy()

# Count the frequency of each category group (ie HD and HighBP and 4 age)
categories, counts = np.unique(data, axis=0, return_counts=True)

# Encode categorical data as integers
encoded_data = np.arange(categories.shape[0])

# Create linkage matrix with frequency information
linkage_matrix = []
for i in range(categories.shape[0]):
    linkage_matrix.append([i, i, counts[i], 0])
linkage_matrix = np.array(linkage_matrix)

# Perform hierarchical clustering
Z = linkage(linkage_matrix[:, 2:], method='ward')

# Plot dendrogram
plt.figure(figsize=(10, 6))
dendrogram(Z, labels=categories, leaf_font_size=12)
plt.xlabel('Data Points')
plt.ylabel('Distance')
plt.title('Hierarchical Clustering Dendrogram of Heart Disease - Age')
plt.show()
# Out:
# /Users/calvinatkins/opt/anaconda3/lib/python3.9/site-packages/matplotlib/text.py:1215: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:

# %%
# Selecting data of interest
data = df[['HeartDiseaseorAttack', 'HighBP', 'GenHlth']]
data.to_numpy()

# Count the frequency of each category group (ie HD and HighBP and 4 age)
categories, counts = np.unique(data, axis=0, return_counts=True)

# Encode categorical data as integers
encoded_data = np.arange(categories.shape[0])

# Create linkage matrix with frequency information
linkage_matrix = []
for i in range(categories.shape[0]):
    linkage_matrix.append([i, i, counts[i], 0])
linkage_matrix = np.array(linkage_matrix)

# Perform hierarchical clustering
Z = linkage(linkage_matrix[:, 2:], method='ward')

# Plot dendrogram
plt.figure(figsize=(10, 6))
dendrogram(Z, labels=categories, leaf_font_size=12)
plt.xlabel('Data Points')
plt.ylabel('Distance')
plt.title('Hierarchical Clustering Dendrogram')
plt.xticks(rotation = 45)
plt.show()

# %%
# Selecting data of interest
data = df[['HD+Stroke', 'Age']]
data.to_numpy()

# Count the frequency of each category group (ie HD and HighBP and 4 age)
categories, counts = np.unique(data, axis=0, return_counts=True)

# Encode categorical data as integers
encoded_data = np.arange(categories.shape[0])

# Create linkage matrix with frequency information
linkage_matrix = []
for i in range(categories.shape[0]):
    linkage_matrix.append([i, i, counts[i], 0])
linkage_matrix = np.array(linkage_matrix)

# Perform hierarchical clustering
Z = linkage(linkage_matrix[:, 2:], method='ward')

# Plot dendrogram
plt.figure(figsize=(10, 6))
dendrogram(Z, labels=categories, leaf_font_size=12)
plt.xlabel('Data Points')
plt.ylabel('Distance')
plt.title('Hierarchical Clustering Dendrogram')
plt.show()

# %%
# Selecting data of interest
data = df[['HeartDiseaseorAttack','GenHlth', 'HighBP']]
data.to_numpy()

# Count the frequency of each category group (ie HD and HighBP and 4 age)
categories, counts = np.unique(data, axis=0, return_counts=True)

# Encode categorical data as integers
encoded_data = np.arange(categories.shape[0])

# Create linkage matrix with frequency information
linkage_matrix = []
for i in range(categories.shape[0]):
    linkage_matrix.append([i, i, counts[i], 0])
linkage_matrix = np.array(linkage_matrix)

# Perform hierarchical clustering
Z = linkage(linkage_matrix[:, 2:], method='ward')

# Plot dendrogram
plt.figure(figsize=(10, 6))
dendrogram(Z, labels=categories, leaf_font_size=12)
plt.xlabel('Data Points')
plt.ylabel('Distance')
plt.title('Hierarchical Clustering Dendrogram of Heart Disease, GenHlth, and Blood Pressure')
plt.xticks(rotation = 45)
plt.show()
