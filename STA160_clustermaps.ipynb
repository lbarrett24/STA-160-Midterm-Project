# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
# Read in cleaned data set
df = pd.read_csv("/Users/calvinatkins/Downloads/Data Sets/HD_indicators_cleaned.csv", index_col = 0)
df.astype('category')
df.dtypes
# Out:
# HeartDiseaseorAttack    int64
# HighBP                  int64
# HighChol                int64
# CholCheck               int64
# BMI                     int64
# Smoker                  int64
# Stroke                  int64
# Diabetes                int64
# PhysActivity            int64
# Fruits                  int64
# Veggies                 int64
# HvyAlcoholConsump       int64
# AnyHealthcare           int64
# NoDocbcCost             int64
# GenHlth                 int64
# MentHlth                int64
# PhysHlth                int64
# DiffWalk                int64
# Sex                     int64
# Age                     int64
# Education               int64
# Income                  int64
# HD+Stroke               int64
# dtype: object

# %%
# create contingency tables with count
# contingency_table = pd.crosstab(df['HighBP'], df['HeartDiseaseorAttack'])

# create contingency table with conditonal probability on row sums
contingency_table = pd.crosstab(df['HighBP'], df['HeartDiseaseorAttack'], normalize='index')

# create clustermap
sns.clustermap(contingency_table, cmap = "coolwarm")
contingency_table
# Out:
# HeartDiseaseorAttack         0         1
# HighBP
# 0                     0.958820  0.041180
# 1                     0.835264  0.164736

# %%
# create contingency tables with count
contingency_table = pd.crosstab(df['HighBP'], [df['HeartDiseaseorAttack'], df['Stroke']])

# create contingency table with conditonal probability on row sums
contingency_table = pd.crosstab(df['HighBP'], [df['HeartDiseaseorAttack'], df['Stroke']], normalize='index')
print(contingency_table)

# create clustermap
sns.clustermap(contingency_table, cmap = "coolwarm")
# Out:
# HeartDiseaseorAttack         0                   1
# Stroke                       0         1         0         1
# HighBP
# 0                     0.945503  0.013317  0.036085  0.005095
# 1                     0.794595  0.040669  0.135341  0.029395

# %%
# create contingency table with conditonal probability on row sums
contingency_table = pd.crosstab([df['Sex'],df['HighBP']], [df['HeartDiseaseorAttack'], df['Stroke']], normalize='index')
print(contingency_table)

# create clustermap
sns.clustermap(contingency_table, cmap = "coolwarm")
# Out:
# HeartDiseaseorAttack         0                   1
# Stroke                       0         1         0         1
# Sex HighBP
# 0   0                 0.957436  0.014101  0.024347  0.004115
#     1                 0.820113  0.044508  0.107904  0.027475
# 1   0                 0.928878  0.012225  0.052437  0.006460
#     1                 0.765847  0.036345  0.166250  0.031558

# %%
# create contingency tables with count
contingency_table = pd.crosstab([df['Age']], [df['HeartDiseaseorAttack']])

# create contingency table with conditonal probability on row sums
contingency_table = pd.crosstab([df['Age']], [df['HeartDiseaseorAttack']], normalize='index')
print(contingency_table)

# create clustermap
sns.clustermap(contingency_table, cmap = "coolwarm")
# Out:
# HeartDiseaseorAttack         0         1
# Age
# 1                     0.994912  0.005088
# 2                     0.992893  0.007107
# 3                     0.988672  0.011328
# 4                     0.986038  0.013962
# 5                     0.978276  0.021724
# 6                     0.964075  0.035925
# 7                     0.945846  0.054154
# 8                     0.926927  0.073073
# 9                     0.898989  0.101011
# 10                    0.869758  0.130242
# 11                    0.832278  0.167722
# 12                    0.806446  0.193554
# 13                    0.760468  0.239532

# %%
# create contingency tables with count
contingency_table = pd.crosstab([df['Smoker'],df['Diabetes']], [df['HeartDiseaseorAttack'], df['Stroke']])

# create contingency table with conditonal probability on row sums
contingency_table = pd.crosstab([df['Age']], [df['HeartDiseaseorAttack'], df['Stroke']], normalize='index')
print(contingency_table)

# create clustermap
sns.clustermap(contingency_table, cmap = "coolwarm")
# Out:
# HeartDiseaseorAttack         0                   1
# Stroke                       0         1         0         1
# Age
# 1                     0.992105  0.002807  0.004211  0.000877
# 2                     0.989997  0.002895  0.006186  0.000921
# 3                     0.983458  0.005214  0.009080  0.002248
# 4                     0.978442  0.007596  0.011647  0.002315
# 5                     0.966764  0.011512  0.019063  0.002661
# 6                     0.951208  0.012866  0.030224  0.005702
# 7                     0.927187  0.018659  0.045375  0.008779
# 8                     0.904742  0.022185  0.060067  0.013006
# 9                     0.872548  0.026441  0.084918  0.016093
# 10                    0.839597  0.030161  0.110083  0.020159
# 11                    0.792589  0.039689  0.141248  0.026473
# 12                    0.757635  0.048811  0.161577  0.031977
# 13                    0.704371  0.056096  0.195646  0.043886

# %%
# create contingency table with conditonal probability on row sums
contingency_table = pd.crosstab([df['Sex'], df['GenHlth']], [df['HeartDiseaseorAttack']], normalize='index')
print(contingency_table)

# create clustermap
sns.clustermap(contingency_table, cmap = "coolwarm")
# Out:
# HeartDiseaseorAttack         0         1
# Sex GenHlth
# 0   1                 0.985952  0.014048
#     2                 0.971170  0.028830
#     3                 0.924490  0.075510
#     4                 0.825106  0.174894
#     5                 0.701845  0.298155
# 1   1                 0.966724  0.033276
#     2                 0.931527  0.068473
#     3                 0.860244  0.139756
#     4                 0.734083  0.265917
#     5                 0.602594  0.397406

# %%
# create contingency table with conditonal probability on row sums
contingency_table = pd.crosstab([df['HighBP'], df['Age']], [df['HeartDiseaseorAttack']], normalize='index')
print(contingency_table)

# create clustermap
sns.clustermap(contingency_table, cmap = "coolwarm")
# Out:
# HeartDiseaseorAttack         0         1
# HighBP Age
# 0      1              0.995776  0.004224
#        2              0.995534  0.004466
#        3              0.992832  0.007168
#        4              0.992447  0.007553
#        5              0.989288  0.010712
#        6              0.984166  0.015834
#        7              0.974014  0.025986
#        8              0.966388  0.033612
#        9              0.949599  0.050401
#        10             0.931574  0.068426
#        11             0.905092  0.094908
#        12             0.875090  0.124910
#        13             0.829630  0.170370
# 1      1              0.985772  0.014228
#        2              0.972758  0.027242
#        3              0.964548  0.035452
#        4              0.957960  0.042040
#        5              0.941727  0.058273
#        6              0.914734  0.085266
#        7              0.895655  0.104345
#        8              0.874557  0.125443
#        9              0.847742  0.152258
#        10             0.822540  0.177460
#        11             0.787542  0.212458
#        12             0.769939  0.230061
#        13             0.723246  0.276754

# %%
# create contingency table with conditonal probability on row sums
contingency_table = pd.crosstab([df['HighBP'], df['Smoker'], df['HighChol'], df['PhysActivity'], df['HvyAlcoholConsump']], [df['HeartDiseaseorAttack']], normalize='index')
print(contingency_table)

# create clustermap
sns.clustermap(contingency_table, cmap = "coolwarm")
# Out:
# HeartDiseaseorAttack                                          0         1
# HighBP Smoker HighChol PhysActivity HvyAlcoholConsump
# 0      0      0        0            0                  0.965069  0.034931
#                                     1                  0.986159  0.013841
#                        1            0                  0.984431  0.015569
#                                     1                  0.991050  0.008950
#               1        0            0                  0.934354  0.065646
#                                     1                  1.000000  0.000000
#                        1            0                  0.953900  0.046100
#                                     1                  0.966763  0.033237
#        1      0        0            0                  0.932424  0.067576
#                                     1                  0.958115  0.041885
#                        1            0                  0.960240  0.039760
#                                     1                  0.978996  0.021004
#               1        0            0                  0.863693  0.136307
#                                     1                  0.928105  0.071895
#                        1            0                  0.907734  0.092266
#                                     1                  0.959253  0.040747
# 1      0      0        0            0                  0.897410  0.102590
#                                     1                  0.923529  0.076471
#                        1            0                  0.932775  0.067225
#                                     1                  0.971292  0.028708
#               1        0            0                  0.805901  0.194099
#                                     1                  0.882812  0.117188
#                        1            0                  0.848427  0.151573
#                                     1                  0.892954  0.107046
#        1      0        0            0                  0.843117  0.156883
#                                     1                  0.908745  0.091255
#                        1            0                  0.886157  0.113843
#                                     1                  0.945749  0.054251
#               1        0            0                  0.705336  0.294664
#                                     1                  0.814570  0.185430
#                        1            0                  0.753992  0.246008
#                                     1                  0.854782  0.145218

# %%
# create contingency table with conditonal probability on row sums
contingency_table = pd.crosstab([df['HighBP'], df['Smoker'], df['HighChol'], df['PhysActivity'], df['HvyAlcoholConsump'], df['NoDocbcCost']],
                                [df['HeartDiseaseorAttack'], df['Stroke']], normalize='index')
print(contingency_table)

# create clustermap
sns.clustermap(contingency_table, cmap = "coolwarm")
# Out:
# HeartDiseaseorAttack                                                      0  \
# Stroke                                                                    0
# HighBP Smoker HighChol PhysActivity HvyAlcoholConsump NoDocbcCost
# 0      0      0        0            0                 0            0.950475
#                                                       1            0.946623
#                                     1                 0            0.964427
#                                                       1            1.000000
#                        1            0                 0            0.977982
# ...                                                                     ...
# 1      1      1        0            1                 1            0.733333
#                        1            0                 0            0.711301
#                                                       1            0.653151
#                                     1                 0            0.825130
#                                                       1            0.733333
#
# HeartDiseaseorAttack                                                         \
# Stroke                                                                    1
# HighBP Smoker HighChol PhysActivity HvyAlcoholConsump NoDocbcCost
# 0      0      0        0            0                 0            0.014473
#                                                       1            0.019608
#                                     1                 0            0.019763
#                                                       1            0.000000
#                        1            0                 0            0.006956
# ...                                                                     ...
# 1      1      1        0            1                 1            0.040000
#                        1            0                 0            0.047128
#                                                       1            0.055342
#                                     1                 0            0.036917
#                                                       1            0.046667
#
# HeartDiseaseorAttack                                                      1  \
# Stroke                                                                    0
# HighBP Smoker HighChol PhysActivity HvyAlcoholConsump NoDocbcCost
# 0      0      0        0            0                 0            0.029851
#                                                       1            0.026144
#                                     1                 0            0.015810
#                                                       1            0.000000
#                        1            0                 0            0.013578
# ...                                                                     ...
# 1      1      1        0            1                 1            0.133333
#                        1            0                 0            0.202832
#                                                       1            0.221370
#                                     1                 0            0.125000
#                                                       1            0.186667
#
# HeartDiseaseorAttack
# Stroke                                                                    1
# HighBP Smoker HighChol PhysActivity HvyAlcoholConsump NoDocbcCost
# 0      0      0        0            0                 0            0.005201
#                                                       1            0.007625
#                                     1                 0            0.000000
#                                                       1            0.000000
#                        1            0                 0            0.001483
# ...                                                                     ...
# 1      1      1        0            1                 1            0.093333
#                        1            0                 0            0.038739
#                                                       1            0.070137
#                                     1                 0            0.012953
#                                                       1            0.033333
#
# [64 rows x 4 columns]

# %%
# create contingency table with conditonal probability on row sums
contingency_table = pd.crosstab([df['PhysHlth'], df['MentHlth'], df['GenHlth']],
                                [df['HeartDiseaseorAttack']], normalize='index')
print(contingency_table)

# create clustermap
sns.clustermap(contingency_table, cmap = "coolwarm")
# Out:
# HeartDiseaseorAttack              0         1
# PhysHlth MentHlth GenHlth
# 1        1        1        0.978914  0.021086
#                   2        0.954184  0.045816
#                   3        0.896079  0.103921
#                   4        0.787924  0.212076
#                   5        0.646774  0.353226
#          2        1        0.976141  0.023859
#                   2        0.969130  0.030870
#                   3        0.931553  0.068447
#                   4        0.839516  0.160484
#                   5        0.700787  0.299213
#          3        1        0.965385  0.034615
#                   2        0.962451  0.037549
#                   3        0.915896  0.084104
#                   4        0.834387  0.165613
#                   5        0.677741  0.322259
# 2        1        1        0.952286  0.047714
#                   2        0.938462  0.061538
#                   3        0.873091  0.126909
#                   4        0.756984  0.243016
#                   5        0.617493  0.382507
#          2        1        0.891892  0.108108
#                   2        0.892857  0.107143
#                   3        0.874802  0.125198
#                   4        0.790412  0.209588
#                   5        0.674419  0.325581
#          3        1        0.914286  0.085714
#                   2        0.955696  0.044304
#                   3        0.903061  0.096939
#                   4        0.806695  0.193305
#                   5        0.694534  0.305466
# 3        1        1        0.929032  0.070968
#                   2        0.922062  0.077938
#                   3        0.860668  0.139332
#                   4        0.763282  0.236718
#                   5        0.627638  0.372362
#          2        1        0.935484  0.064516
#                   2        0.938776  0.061224
#                   3        0.896130  0.103870
#                   4        0.784344  0.215656
#                   5        0.695238  0.304762
#          3        1        0.931034  0.068966
#                   2        0.893701  0.106299
#                   3        0.870718  0.129282
#                   4        0.808372  0.191628
#                   5        0.695961  0.304039
